# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 2.0.14

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# %matplotlib inline

# %%
cf.go_offline()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
df = pd.DataFrame(np.random.randn(100,4), columns=('A B C D'.split()))

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.742431 -0.445813  1.653357  0.666608
# 1 -1.795814 -0.275951 -0.199592  0.568156
# 2  0.888157  1.166643 -0.310680 -0.161275
# 3 -0.056183  0.097442  0.708294  0.286552
# 4  2.447910 -0.289917  0.862565 -0.124310

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[1,2,3] })

# %%
df2
# Out:
#   Category  Values
# 0        A       1
# 1        B       2
# 2        C       3

# %%
df.iplot()  #Interactive Plot
# Out:
# <div id="abcf0308-70a3-4f22-a512-db75e733fee4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("abcf0308-70a3-4f22-a512-db75e733fee4", [{"name": "A", "text": "", "mode": "lines", "y": [0.7424306468469334, -1.7958140881024287, 0.8881566416191343, -0.056182594273686416, 2.447910347212442, 0.44475750009525405, -1.0936929346379962, -0.15567358725502017, -0.6725077782419647, -1.3078016742213834, 0.3278080901473933, -0.17333830132881445, -1.0372692813156252, 0.1892666709268481, -0.9701928851243596, 1.5146943830667223, -0.02513381975620712, -0.5179550603530628, -1.9432878124728812, 0.5703678164295874, 0.09343944839846678, 1.0635616905111558, -0.7971017526931615, 1.0909064179180052, 0.5880622057074076, -0.2663197788052499, 0.6099820301412324, 0.8314359277362973, 0.24557628598346848, 0.21534884932366677, 1.4
# ...

# %%
df.iplot(kind='scatter', x='A', y="B", mode="markers", size=10) # Scatter Plot
# Out:
# <div id="70e51e7a-7efa-4488-a849-77e5c2382a2b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("70e51e7a-7efa-4488-a849-77e5c2382a2b", [{"name": "B", "text": "", "marker": {"symbol": "dot", "size": 10}, "mode": "markers", "y": [-0.445812602189535, -0.2759508686861425, 1.1666429583683184, 0.09744196603679707, -0.28991710457618575, 0.9672992976992992, -0.9902791806593976, 0.2850859993711379, -0.5592473655457952, -0.5592945952868548, -0.29711440501088504, 0.32456406715372244, -1.351407526657947, -2.041747585471188, -0.6684769765115901, -2.352960046700637, 0.9137841886043203, -0.8925840615030218, -0.19907621843380147, -0.3716987782870331, -1.5298641277727345, 0.2932261218594203, -0.0943821557846436, 0.01566361718103735, -0.2889453326234111, 1.1543796672493607, 1.0754065501834214, -1.1531449806561969, -2
# ...

# %%
df2.iplot(kind='bar', x='Category',y='Values' )
# Out:
# <div id="0869fa4c-a237-4c9d-8555-1e7e53f3ebc2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0869fa4c-a237-4c9d-8555-1e7e53f3ebc2", [{"name": "Values", "text": "", "y": [1, 2, 3], "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "x": ["A", "B", "C"], "type": "bar", "orientation": "v"}], {"paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "xaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "yaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "titlefont": {"color": "#4D5663"}, "legend": {"bgcolor": "#F5F6F9", "font": {"
# ...

# %%
#Group By and Aggregates
df.sum().iplot(kind='bar')
# Out:
# <div id="02194237-6100-49e7-9315-1d9a0db98c5f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("02194237-6100-49e7-9315-1d9a0db98c5f", [{"name": "None", "text": "", "y": [-10.240483019655358, -2.6567193790901626, 19.00959046893656, -21.458664647847254], "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "x": ["A", "B", "C", "D"], "type": "bar", "orientation": "v"}], {"paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "xaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "yaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "t
# ...

# %%
df.iplot(kind='box')
# Out:
# <div id="53471c65-30fc-403b-9a0a-68653d776d0e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("53471c65-30fc-403b-9a0a-68653d776d0e", [{"name": "A", "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "y": [0.7424306468469334, -1.7958140881024287, 0.8881566416191343, -0.056182594273686416, 2.447910347212442, 0.44475750009525405, -1.0936929346379962, -0.15567358725502017, -0.6725077782419647, -1.3078016742213834, 0.3278080901473933, -0.17333830132881445, -1.0372692813156252, 0.1892666709268481, -0.9701928851243596, 1.5146943830667223, -0.02513381975620712, -0.5179550603530628, -1.9432878124728812, 0.5703678164295874, 0.09343944839846678, 1.0635616905111558, -0.7971017526931615, 1.0909064179180052, 0.5880622057074076, -0.2663197788052499, 0.6099820301412324, 0.8314359277362973, 0.24557628598346848, 0.215
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[500,400,300,200,100], 'z':[10,20,30,40,50]})

# %%
df3
# Out:
#    x    y   z
# 0  1  500  10
# 1  2  400  20
# 2  3  300  30
# 3  4  200  40
# 4  5  100  50

# %%
#3D Plot
df3.iplot(kind='surface', colorscale="rdylbu")
# Out:
# <div id="71094948-bc84-4882-8997-64f0b46eb891" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("71094948-bc84-4882-8997-64f0b46eb891", [{"y": ["x", "y", "z"], "x": [0, 1, 2, 3, 4], "z": [[1, 2, 3, 4, 5], [500, 400, 300, 200, 100], [10, 20, 30, 40, 50]], "type": "surface", "colorscale": [[0.0, "rgb(165,0,38)"], [0.1, "rgb(215,48,39)"], [0.2, "rgb(244,109,67)"], [0.3, "rgb(253,174,97)"], [0.4, "rgb(254,224,144)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(224,243,248)"], [0.7, "rgb(171,217,233)"], [0.8, "rgb(116,173,209)"], [0.9, "rgb(69,117,180)"], [1.0, "rgb(49,54,149)"]]}], {"paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "xaxis1": {"tickfont": {"color": "#4D5663"}, "title": "", "showgrid": true, "zerolinecolor": "#E1E5ED", "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}}, "yaxis1": {"
# ...

# %%
df['A'].iplot(kind='hist', bins=50)
# Out:
# <div id="1b35824b-4a39-4941-afef-aa08bc185c23" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1b35824b-4a39-4941-afef-aa08bc185c23", [{"opacity": 0.8, "name": "A", "histnorm": "", "nbinsx": 50, "histfunc": "count", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "x": [0.7424306468469334, -1.7958140881024287, 0.8881566416191343, -0.056182594273686416, 2.447910347212442, 0.44475750009525405, -1.0936929346379962, -0.15567358725502017, -0.6725077782419647, -1.3078016742213834, 0.3278080901473933, -0.17333830132881445, -1.0372692813156252, 0.1892666709268481, -0.9701928851243596, 1.5146943830667223, -0.02513381975620712, -0.5179550603530628, -1.9432878124728812, 0.5703678164295874, 0.09343944839846678, 1.0635616905111558, -0.7971017526931615, 1.09090641791800
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div id="372b76bb-cfdd-49bd-ba2f-219bd270b3aa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("372b76bb-cfdd-49bd-ba2f-219bd270b3aa", [{"opacity": 0.8, "name": "A", "histnorm": "", "histfunc": "count", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "x": [0.7424306468469334, -1.7958140881024287, 0.8881566416191343, -0.056182594273686416, 2.447910347212442, 0.44475750009525405, -1.0936929346379962, -0.15567358725502017, -0.6725077782419647, -1.3078016742213834, 0.3278080901473933, -0.17333830132881445, -1.0372692813156252, 0.1892666709268481, -0.9701928851243596, 1.5146943830667223, -0.02513381975620712, -0.5179550603530628, -1.9432878124728812, 0.5703678164295874, 0.09343944839846678, 1.0635616905111558, -0.7971017526931615, 1.0909064179180052, 0.58806220
# ...

# %%
df.iplot(kind='bubble', x='A', y='B', size='D')
# Out:
# <div id="94c238c7-33db-432c-9c8a-68d0c9bafe12" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("94c238c7-33db-432c-9c8a-68d0c9bafe12", [{"text": "", "marker": {"color": ["rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 153, 51)", "rgb(255, 
# ...

# %%
df.scatter_matrix()
# Out:
# <div id="5356d105-8d87-4efe-9306-8e6cac6a9a31" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5356d105-8d87-4efe-9306-8e6cac6a9a31", [{"opacity": 0.8, "orientation": "v", "yaxis": "y1", "histnorm": "", "histfunc": "count", "nbinsx": 10, "xaxis": "x1", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "x": [0.7424306468469334, -1.7958140881024287, 0.8881566416191343, -0.056182594273686416, 2.447910347212442, 0.44475750009525405, -1.0936929346379962, -0.15567358725502017, -0.6725077782419647, -1.3078016742213834, 0.3278080901473933, -0.17333830132881445, -1.0372692813156252, 0.1892666709268481, -0.9701928851243596, 1.5146943830667223, -0.02513381975620712, -0.5179550603530628, -1.9432878124728812, 0.5703678164295874, 0.09343944839846678, 1.0635616905111558, 
# ...
